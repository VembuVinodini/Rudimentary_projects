# %%
import googleapiclient.discovery

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key="AIzaSyA8GjXFC4mONX3jSN0nt5MIJv6Gf8ggxZs"
youtube =build("youtube","v3",developerKey=api_key)
channel_id="UCvhU9qF1xtUsFXdKrcJxbFA"

# %%
# step 1 - to fetch channel details

def channel_details(channel_id):
    request = youtube.channels().list(part="snippet,contentDetails,statistics",id=channel_id)
    response = request.execute()
    channel_details={
        'channel_name': [response["items"][0]['snippet']['title']],
        ' channel_id': [response['items'][0]['id']],
        'subscription_count ': [response['items'][0]['statistics']['subscriberCount']],
        'channel_views': [response['items'][0]['statistics']['viewCount']],
        'channel_description': [response['items'][0]['snippet']['description']],
         'playlist_id': [response['items'][0]['contentDetails']['relatedPlaylists']['uploads']]
    }


    return pd.DataFrame(channel_details)
channel_df= channel_details(channel_id)
channel_df
# Out:
#      channel_name                channel_id subscription_count  channel_views  \
# 0  Curious Freaks  UCvhU9qF1xtUsFXdKrcJxbFA              200000      14332563
#
#                                  channel_description               playlist_id
# 0  Life is short but the way you build yourself a...  UUvhU9qF1xtUsFXdKrcJxbFA

# %%
# step 2 - to fetch playlist details

import pandas as pd

def get_playlists(channel_id):
    dic = {"channel_id": [], "playlist_id": [], 'publishedAt': [], 'playlist_title': [], 'playlist_video_count': []}
    request = youtube.playlists().list(part='snippet,contentDetails', channelId=channel_id, maxResults=10)
    response = request.execute()
    for i in response['items']:
        dic['channel_id'].append(channel_id)
        dic['playlist_id'].append(i['id'])
        dic['publishedAt'].append(i['snippet']['publishedAt'])
        dic['playlist_title'].append(i['snippet']['title'])
        dic['playlist_video_count'].append(i['contentDetails']['itemCount'])

    while response.get('nextPageToken') is not None:
        request = youtube.playlists().list(part='snippet,contentDetails', channelId=channel_id, maxResults=10,
                                           pageToken=response.get('nextPageToken'))
        response = request.execute()
        for i in response['items']:
            dic['channel_id'].append(channel_id)
            dic['playlist_id'].append(i['id'])
            dic['publishedAt'].append(i['snippet']['publishedAt'])
            dic['playlist_title'].append(i['snippet']['title'])
            dic['playlist_video_count'].append(i['contentDetails']['itemCount'])

    return pd.DataFrame(dic)

# to display the playlist
channel_id = "UCvhU9qF1xtUsFXdKrcJxbFA"
playlist_df = get_playlists(channel_id)
playlist_df
# Out:
#                   channel_id                         playlist_id  \
# 0   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifxctnY3FxfpwNXytlX_RhfN
# 1   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifwTkdpbhwKZqFUj6JZDaFt4
# 2   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifzLgWg4exhGZs-ITDQ79XOT
# 3   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifxRi6rugw6F4MH2jWOlzTvV
# 4   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifwwFe4ZaTe9XV3s_BC_yS8i
# 5   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifzpM3JDjDch3qpUngTo3wRG
# 6   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifxsz63PLE5BCxFN8iFY-T0F
# 7   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifwvziROk_mJFju6cpbSN1Do
# 8   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifylD5oMtPTXTCfBu6rI6MeY
# 9   UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifyf2XTH0Dy385tEBecZQ9yr
# 10  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifzuZiRLIsriTV_17y_m_LlH
# 11  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifyRnlhlWWQ2h6JxZCWmCW1w
# 12  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifzAbbEXpjZAhQqVeotx90B-
# 13  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifwisff71PYmZiF9j6UwNb2U
# 14  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifwLxCNxiwCe3TDcMPrmOd9t
# 15  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifyG9bpsSb939EXYq4mFZs9J
# 16  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifyeaSpKprYGSl7Cm_N3F-la
# 17  UCvhU9qF1xtUsFXdKrcJxbFA  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd
#
#              publishedAt        playlist_title  playlist_video_count
# 0   2023-06-24T15:11:12Z                Resume                     2
# 1   2023-02-12T05:59:00Z            Board exam                     1
# 2   2023-01-03T10:52:29Z           Career Path                     8
# 3   2022-12-02T14:53:00Z  Curious talk-Podcast                     5
# 4   2022-03-07T12:36:47Z        Curiosity Zone                     9
# 5   2022-02-23T13:33:45Z          TriumphQuest                     1
# 6   2022-02-20T10:40:02Z             Placement                    18
# 7   2022-01-09T20:05:21Z      College students                    18
# 8   2022-01-09T20:05:18Z      College students                    17
# 9   2021-12-24T09:30:39Z          Life lessons                    14
# 10  2021-12-17T10:58:59Z                Coding                    17
# 11  2021-12-09T11:00:36Z          Stock Market                     1
# 12  2021-12-09T11:00:34Z          Stock Market                     1
# 13  2021-12-01T09:38:17Z            Interviews                     5
# 14  2021-11-29T06:39:37Z               Studies                    35
# 15  2021-11-27T07:49:10Z       Must know truth                    16
# 16  2021-11-25T15:55:15Z                Shorts                    12
# 17  2021-11-24T03:21:48Z         Money Earning                     5

# %%
import IPython
IPython.get_ipython().config.IPKernelApp.iopub_data_rate_limit = 1000000000  # Set a higher value (e.g., 1 GB/s)

# %%
# step 3 - fetch video details

import pandas as pd
from googleapiclient.discovery import build

# Set up the YouTube Data API credentials
api_key = "AIzaSyA8GjXFC4mONX3jSN0nt5MIJv6Gf8ggxZs"
youtube = build("youtube", "v3", developerKey=api_key)

def fetch_video_details(channel_id):
    videos = []
    next_page_token = None

    while True:
        # to Fetch the playlist IDs for the channel
        playlist_request = youtube.playlists().list(
            part="id",
            channelId=channel_id,
            maxResults=10,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()
        playlist_ids = [item['id'] for item in playlist_response['items']]

        # to Fetch video details for each playlist
        for playlist_id in playlist_ids:
            video_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=playlist_id,
                maxResults=10
            )
            video_response = video_request.execute()

            video_ids = [item['contentDetails']['videoId'] for item in video_response['items']]
            video_stats_request = youtube.videos().list(
                part="statistics",
                id=",".join(video_ids),
                maxResults=10
            )
            video_stats_response = video_stats_request.execute()

            for item in video_response['items']:
                video_id = item['contentDetails']['videoId']
                video_title = item['snippet']['title']
                video_description = item['snippet']['description']
                video_published_date = item['snippet']['publishedAt']
                video_duration = item['contentDetails'].get('duration', 'Duration not available')

                # to find the statistics for the current video
                video_statistics = None
                for stats_item in video_stats_response['items']:
                    if stats_item['id'] == video_id:
                        video_statistics = stats_item['statistics']
                        break

                video_view_count = video_statistics.get('viewCount', 0) if video_statistics else 0
                video_like_count = video_statistics.get('likeCount', 0) if video_statistics else 0
                video_dislike_count = video_statistics.get('dislikeCount', 0) if video_statistics else 0
                video_favorite_count = video_statistics.get('favoriteCount', 0) if video_statistics else 0
                video_comment_count = video_statistics.get('commentCount', 0) if video_statistics else 0
                video_thumbnail = item['snippet']['thumbnails'].get('default', {}).get('url', 'Thumbnail not available')

                videos.append({
                    'playlist_id': playlist_id,
                    'video_id': video_id,
                    'video_title': video_title,
                    'video_description': video_description,
                    'video_published_date': video_published_date,
                    'video_duration': video_duration,
                    'video_view_count': video_view_count,
                    'video_like_count': video_like_count,
                    'video_dislike_count': video_dislike_count,
                    'video_favorite_count': video_favorite_count,
                    'video_comment_count': video_comment_count,
                    'video_thumbnail': video_thumbnail
                })

        # to check if there are more playlists to fetch
        next_page_token = playlist_response.get('nextPageToken')
        if not next_page_token:
            break

    return videos


channel_id = "UCvhU9qF1xtUsFXdKrcJxbFA"
videos = fetch_video_details(channel_id)
video_df = pd.DataFrame(videos)

print(video_df)
# Out:
#                             playlist_id     video_id  \
# 0    PLV6alN9J6ifxctnY3FxfpwNXytlX_RhfN  q6kGD1Gu5go
# 1    PLV6alN9J6ifxctnY3FxfpwNXytlX_RhfN  e-MNXhqFsro
# 2    PLV6alN9J6ifwTkdpbhwKZqFUj6JZDaFt4  3lsIv5sp04Y
# 3    PLV6alN9J6ifzLgWg4exhGZs-ITDQ79XOT  qc4yHkyRkaY
# 4    PLV6alN9J6ifzLgWg4exhGZs-ITDQ79XOT  olOIIXOM9Qo
# ..                                  ...          ...
# 113  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd  HpHx3dtDMjs
# 114  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd  V46_BRsGrhs
# 115  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd  aJO_pF8cRxc
# 116  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd  rZPRFlO-BGg
# 117  PLV6alN9J6ifyRwarART7OJpcTcLnvU2hd  PuqFyCWjqzo
#
#                                            video_title  \
# 0    Stop this in your resume to get job😡🔴150 fresh...
# 1    How to build PERFECT RESUME to get HIGH PAYING...
# 2    7 EXAM toppers reveal their secret study trick...
# 3    Fastest way to get IT JOB in 60DAYS🔥🚀How to be...
# 4    How to learn UX/UI DESIGN in Just 30Days(தமிழ்...
# ..                                                 ...
# 113  7 best ways to MAKE MONEY ONLINE for COLLEGE S...
# 114  Top 8 High income skills of 2022(தமிழ்)🔥| EARN...
# 115  How to become crorepathi - NoOne tells u🔥Perso...
# 116  HOW TO EARN MONEY ON AMAZON 2022 with 0 skills...
# 117  4 Money mistakes that Made me LOSE HUGE MONEY ...
#
#                                      video_description  video_published_date  \
# 0    I Reviewed 150 RESUMES, Shocked with worst RES...  2023-06-24T15:11:16Z
# 1    Revealing the PERFECT RESUME TEMPLATE to get a...  2023-06-24T15:12:11Z
# 2    I asked 7 lifetime toppers for their study tri...  2023-02-12T05:59:10Z
# 3    Fastest WAY to become SOFTWARE TESTER and get ...  2023-01-03T10:52:39Z
# 4    How to become UX/UI designer in Just 3Months🔥😱...  2023-01-03T10:56:27Z
# ..                                                 ...                   ...
# 113  7 best ways to MAKE MONEY ONLINE for COLLEGE S...  2021-11-24T03:21:57Z
# 114  TOP 8 HIGH PAYING SKILLS to EARN MONEY in 2022...  2022-01-04T09:45:59Z
# 115  Only way to financial freedom🔥Personal finance...  2022-02-07T07:39:39Z
# 116  HOW TO EARN MONEY ON AMAZON 2022 with 0 skills...  2022-04-01T07:05:17Z
# 117  Everyone learn from our mistakes, so when we m...  2022-05-28T06:31:47Z
#
#              video_duration video_view_count video_like_count  \
# 0    Duration not available            56016             1786
# 1    Duration not available           506157            13559
# 2    Duration not available            19434              896
# 3    Duration not available            56931             1712
# 4    Duration not available           204330             7883
# ..                      ...              ...              ...
# 113  Duration not available            33955             1637
# 114  Duration not available            25637             1013
# 115  Duration not available             3741              157
# 116  Duration not available            24966              708
# 117  Duration not available             6015              245
#
#      video_dislike_count video_favorite_count video_comment_count  \
# 0                      0                    0                  97
# 1                      0                    0                 274
# 2                      0                    0                  50
# 3                      0                    0                 234
# 4                      0                    0                 330
# ..                   ...                  ...                 ...
# 113                    0                    0                 164
# 114                    0                    0                  69
# 115                    0                    0                  26
# 116                    0                    0                  29
# 117                    0                    0                  37
#
#                                     video_thumbnail
# 0    https://i.ytimg.com/vi/q6kGD1Gu5go/default.jpg
# 1    https://i.ytimg.com/vi/e-MNXhqFsro/default.jpg
# 2    https://i.ytimg.com/vi/3lsIv5sp04Y/default.jpg
# 3    https://i.ytimg.com/vi/qc4yHkyRkaY/default.jpg
# 4    https://i.ytimg.com/vi/olOIIXOM9Qo/default.jpg
# ..                                              ...
# 113  https://i.ytimg.com/vi/HpHx3dtDMjs/default.jpg
# 114  https://i.ytimg.com/vi/V46_BRsGrhs/default.jpg
# 115  https://i.ytimg.com/vi/aJO_pF8cRxc/default.jpg
# 116  https://i.ytimg.com/vi/rZPRFlO-BGg/default.jpg
# 117  https://i.ytimg.com/vi/PuqFyCWjqzo/default.jpg
#
# [118 rows x 12 columns]

# %%
# step 4 - to fetch comment details

import pandas as pd
from googleapiclient.discovery import build

api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyA8GjXFC4mONX3jSN0nt5MIJv6Gf8ggxZs"
youtube = build(api_service_name, api_version, developerKey=api_key)

def fetch_comments(channel_id):
    # to fetch videos from the channel using the YouTube Data API
    videos = []
    request = youtube.search().list(
        part="id",
        channelId=channel_id,
        maxResults=10,
        type="video"
    )
    response = request.execute()

    while response.get('items'):
        for item in response['items']:
            video_id = item['id']['videoId']
            comments = fetch_comments_for_video(video_id)
            videos.extend(comments)

        if 'nextPageToken' in response:
            request = youtube.search().list(
                part="id",
                channelId=channel_id,
                maxResults=10,
                type="video",
                pageToken=response['nextPageToken']
            )
            response = request.execute()
        else:
            break

    return videos

def fetch_comments_for_video(video_id):
    # to fetch comments for a video using the YouTube Data API
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=50
    )
    response = request.execute()

    while response.get('items'):
        for item in response['items']:
            comment_id = item['id']
            comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_likes = item['snippet']['topLevelComment']['snippet']['likeCount']
            comment_published_date = item['snippet']['topLevelComment']['snippet']['publishedAt']
            comment_author = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

            comments.append({
                'video_id': video_id,
                'comment_id': comment_id,
                'comment_text': comment_text,
                'comment_likes': comment_likes,
                'comment_published_date': comment_published_date,
                'comment_author': comment_author
            })

        if 'nextPageToken' in response:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50,
                pageToken=response['nextPageToken']
            )
            response = request.execute()
        else:
            break

    return comments

channel_id = "UCvhU9qF1xtUsFXdKrcJxbFA"
videos = fetch_comments(channel_id)
comments_df = pd.DataFrame(videos)

print(comments_df)
# Out:
#           video_id                  comment_id  \
# 0      DiET_TgiHNc  Ugyzcqa9R1XCan4HAQ94AaABAg
# 1      DiET_TgiHNc  Ugw_zZczPearLuztbMR4AaABAg
# 2      DiET_TgiHNc  UgynOUpH8E65mLRC1BB4AaABAg
# 3      DiET_TgiHNc  UgxjtCCOehY6_g3nBZZ4AaABAg
# 4      DiET_TgiHNc  UgzBKxQ3xz9hMtg67-l4AaABAg
# ...            ...                         ...
# 19626  tViZKFPxgQ0  UgxxuZLblpRhbcbyosV4AaABAg
# 19627  tViZKFPxgQ0  UgzSfhNAcM0nFU6ajwZ4AaABAg
# 19628  tViZKFPxgQ0  UgxtVto__BfEVsKsxzt4AaABAg
# 19629  tViZKFPxgQ0  UgzOolilG4tkRGkeAwF4AaABAg
# 19630  tViZKFPxgQ0  UgzcKc2DEVt6aY-9r1p4AaABAg
#
#                                             comment_text  comment_likes  \
# 0      Freaks,<br>Do share it with your friends to wh...             38
# 1                                        Promising words              0
# 2            Now I&#39;m failure like Rohan last 3 years              0
# 3       Hii akka you looks like a actress Manjuma mohan🥰              0
# 4                                             Love u sis              0
# ...                                                  ...            ...
# 19626  It was a good video it will help us to reduce ...             18
# 19627                                Use full video akka              1
# 19628                                        First view😍              0
# 19629                                            Hi akka              0
# 19630                                 Amazing hacks akka              3
#
#       comment_published_date         comment_author
# 0       2022-12-10T08:30:01Z         Curious Freaks
# 1       2023-06-19T15:00:45Z           Karthi Keyan
# 2       2023-06-14T06:33:28Z          GANESH Venkat
# 3       2023-06-06T02:04:01Z  Munusamy p Munusamy p
# 4       2023-05-30T16:00:12Z  Pavithradevi Devipavi
# ...                      ...                    ...
# 19626   2022-02-28T11:37:36Z        Jagadishan Jaga
# 19627   2022-02-28T11:35:55Z          Karnan Vishnu
# 19628   2022-02-28T11:35:01Z             charumathi
# 19629   2022-02-28T11:34:55Z           Samsung A10s
# 19630   2022-02-28T11:34:51Z           Samsung A10s
#
# [19631 rows x 6 columns]
